# %% [markdown]
# ## LAB TASK 5

# %% [markdown]
# ## HOSPITAL MANAGEMENT SYSTEM

# %%
while True:
    print("----------------National Medical Centre Hospital-----------------")
    print("---------------------------Reception-----------------------------")
    print("\n----------------PATIENT INFORMATION------------------")
    A = input("Patient No.: ")
    B = int(input("Id: "))
    C = input("Name: ")
    D = input("Father Name: ")
    E = int(input("Age: "))
    F = input("Gender: ")
    G = (input("Blood Pressure: "))
    H = int(input("Temperature: "))
    I = int(input("Weight: "))

#Prescription given by doctor.
    from prettytable import PrettyTable
    X = PrettyTable()
    print("\n ******************************")
    X.field_names=[input(" ")]
    X.add_row([input("1: ")])
    X.add_row([input("2: ")])
    X.add_row([input("3: ")])
    X.add_row([input("4: ")])
    print(X)

#Bill of medicines.
    from prettytable import PrettyTable
    A = PrettyTable()
    print("\n **********************************")
    A.field_names=[input(" "), input(" ")]
    Medicine_1=input("1: ")
    Price_1=int(input("2: "))
    Medicine_2=input("3: ")
    Price_2=int(input("4: "))
    Medicine_3=input("5: ")
    Price_3=int(input("6: "))
    Medicine_4=input("7: ")
    Price_4=int(input("8: "))
    
    total=Price_1 + Price_2 + Price_3  + Price_4
    
    A.add_row([Medicine_1, Price_1])
    A.add_row([Medicine_2, Price_2])
    A.add_row([Medicine_3, Price_3])
    A.add_row([Medicine_4, Price_4])
    A.add_row(["Total", total])
    print(A)
# Out:
# ----------------National Medical Centre Hospital-----------------
# ---------------------------Reception-----------------------------
#
# ----------------PATIENT INFORMATION------------------
# Patient No.: 01
# Id: 1001
# Name: ABC 1
# Father Name: XYZ 1
# Age: 30
# Gender: Male
# Blood Pressure: 130/85
# Temperature: 102
# Weight: 65
#
#  ******************************
#  Medicines
# 1: Panadol
# 2: Brufen
# 3: Concor
# 4: Acefyl
# +-----------+
# | Medicines |
# +-----------+
# |  Panadol  |
# |   Brufen  |
# |   Concor  |
# |   Acefyl  |
# +-----------+
#
#  **********************************
#  Medicines
#  Price
# 1: Panadol
# 2: 100
# 3: Brufen
# 4: 130
# 5: Concor
# 6: 200
# 7: Acefyl
# 8: 180
# +-----------+-------+
# | Medicines | Price |
# +-----------+-------+
# |  Panadol  |  100  |
# |   Brufen  |  130  |
# |   Concor  |  200  |
# |   Acefyl  |  180  |
# |   Total   |  610  |
# +-----------+-------+
# ----------------National Medical Centre Hospital-----------------
# ...
